# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import numpy as np 
import os
import json
import pprint as pprint
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0          0      whitehorse  60.7161 -135.0538    -13.83        81
# 1          1  puerto natales -51.7236  -72.4875     10.50        78
# 2          2       hithadhoo  -0.6000   73.0833     28.21        74
# 3          3           agria  47.9026   20.3733      6.32        77
# 4          4         ushuaia -54.8000  -68.3000     15.81        39
# ..       ...             ...      ...       ...       ...       ...
# 524      524         rosetta  31.4044   30.4164     15.02        82
# 525      525          ankang  32.6800  109.0172      4.96        62
# 526      526         quellon -43.1167  -73.6167     11.33        74
# 527      527        marshall  34.3834  -86.3333     11.86        64
# 528      528         pitimbu  -7.4706  -34.8086     28.33        78
#
#      Cloudiness  Wind Speed Country        Date
# 0            75        2.06      CA  1707270499
# 1            71        0.88      CL  1707270515
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot

city_data_map = city_data_df.hvplot.points("Lat", "Lng", 
                                          geo = True,
                                          title= "Size of City Based on Humidity",
                                          frame_width = 800,
                                          frame_height = 600,
                                          size = "Humidity",
                                          scale = 0.5, 
                                          color = "City")




# Display the map
city_data_map
# Out:
# :Points   [Lat,Lng]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
clean_city_data = city_data_df


clean_city_data = clean_city_data.loc[(clean_city_data["Max Temp"] < 40) & (clean_city_data["Max Temp"] > 25)]
clean_city_data = clean_city_data.loc[(clean_city_data["Wind Speed"] <10)]
clean_city_data = clean_city_data.loc[(clean_city_data["Humidity"]  < 70)]

# Drop any rows with null values
clean_city_data = clean_city_data.dropna()

# Display sample data
clean_city_data
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 16        16        port mathurin -19.6833   63.4167     26.91        69
# 42        42                  alo   7.4178    6.7371     25.24        20
# 46        46       margaret river -33.9500  115.0667     26.03        35
# 51        51                lihue  21.9789 -159.3672     26.58        63
# 63        63            carnarvon -24.8667  113.6333     32.67        40
# 99        99               kokopo  -4.3520  152.2633     29.88        68
# 103      103          sao vicente -23.9631  -46.3919     27.37        26
# 105      105                myeik  12.4333   98.6000     25.39        61
# 111      111                bowen -20.0167  148.2333     31.17        61
# 130      130        santa sylvina -27.8326  -61.1375     26.70        63
# 134      134    wailua homesteads  22.0669 -159.3780     26.24        64
# 144      144              isabela   6.7085  121.9711     27.03        68
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_city_data

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ''

# Display sample data
hotel_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 16        16        port mathurin -19.6833   63.4167     26.91        69
# 42        42                  alo   7.4178    6.7371     25.24        20
# 46        46       margaret river -33.9500  115.0667     26.03        35
# 51        51                lihue  21.9789 -159.3672     26.58        63
# 63        63            carnarvon -24.8667  113.6333     32.67        40
# 99        99               kokopo  -4.3520  152.2633     29.88        68
# 103      103          sao vicente -23.9631  -46.3919     27.37        26
# 105      105                myeik  12.4333   98.6000     25.39        61
# 111      111                bowen -20.0167  148.2333     31.17        61
# 130      130        santa sylvina -27.8326  -61.1375     26.70        63
# 134      134    wailua homesteads  22.0669 -159.3780     26.24        64
# 144      144              isabela   6.7085  121.9711     27.03        68
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",
          "apikey" : geoapify_key}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"

   
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?



    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port mathurin - nearest hotel: No hotel found
# alo - nearest hotel: No hotel found
# margaret river - nearest hotel: No hotel found
# lihue - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# kokopo - nearest hotel: No hotel found
# sao vicente - nearest hotel: No hotel found
# myeik - nearest hotel: No hotel found
# bowen - nearest hotel: No hotel found
# santa sylvina - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: No hotel found
# isabela - nearest hotel: No hotel found
# saipan - nearest hotel: No hotel found
# callao - nearest hotel: No hotel found
# phan rang-thap cham - nearest hotel: No hotel found
# quezon - nearest hotel: No hotel found
# motueka - nearest hotel: No hotel found
# jucas - nearest hotel: No hotel found
# chamical - nearest hotel: No hotel found
# mount isa - nearest hotel: No hotel found
# kailua-kona - nearest hotel: No hotel found
# kone - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_plot = hotel_df.hvplot.points("Lng", "Lat", geo=True, titles="OSM",
                                   frame_width=900, frame_height=900, size="Humidity",
                                   color="city", alpha=0.8, hover_col=["Hotel Name", "Country"])

# Display the map
hotel_plot
# Out:
# WARNING:param.main: hover_col option not found for points plot with bokeh; similar options include: ['hover_color', 'hover_line_color', 'hover_fill_color']
# WARNING:param.main: titles option not found for points plot with bokeh; similar options include: ['title', 'tiles']
# :Points   [Lng,Lat]   (Humidity)
